# %%
import time
import pandas as pd
import numpy as np

CITY_DATA = { 'chicago': 'chicago.csv',
              'new york city': 'new_york_city.csv',
              'washington': 'washington.csv' }

def get_filters():
    """
    Asks user to specify a city, month, and day to analyze.

    Returns:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    """
    print('Hello! Let\'s explore some US bikeshare data!')
    # TO DO: get user input for city (chicago, new york city, washington). HINT: Use a while loop to handle invalid inputs
    
    
    city=input('please input city(chicago, new york city, washington)').lower()
    while city not in CITY_DATA.keys():
        print('please enter a valid city')
        city=input('enter name of the city here(chicago, new york city, washington)').lower()
                
                   
    # TO DO: get user input for month (all, january, february, ... , june)
    months=['january','february','march','april','may','june','all']
    month=input('please input month (all, january, february, march,april,may , june)').lower()
    while month not in months:
        print('enter a valid name')
        input('inter valid name of moth please(all,january,february,march,april,may,june)').lower()
        if monht in months:
            break
        
    # TO DO: get user input for day of week (all, monday, tuesday, ... sunday)
    days=['Monday','Tuesday','Wendnesday','Thrusday','Friday','Saturday','Sunday','All']
    day=input('please input day of week(all,monday ,tuesday,wendnesday,thrusday,friday,sunday)').title() 
    
    while day not in days:
        print('enter a correct answer')
        day=input('please input day of week(all,monday ,tuesday,wendnesday,thrusday,friday,sunday)').title()
            
    print('-'*40)
    return city, month, day

# %%
def load_data(city, month, day):
    """
    Loads data for the specified city and filters by month and day if applicable.

    Args:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    Returns:
        df - Pandas DataFrame containing city data filtered by month and day
    """
    df=pd.read_csv(CITY_DATA[city])
    
    
    # convert start time  to datetime     
    df['Start Time']=pd.to_datetime(df['Start Time'])                                
                                    
    # extract day form datetim
    df['day']=df['Start Time'].dt.weekday
                                    
                                    
    # extract month from datetime 
    df['month']=df['Start Time'].dt.month
                                    
                                    
    # extract hour from datetime
    df['start_hour']=df['Start Time'].dt.hour
     
                                    
    # filtering month                                
    if month != 'all':
        months=['january','february','march','april','may','june']                                    
        month=months.index(month)+1
        df=df[df['month']==month]
    
                                    
    # filtering day                                 
    days=['Monday','Tuesday','Wendnesday','Thrusday','Friday','Saturday','Sunday','All']                              
    if day != 'All':
        df=df[df['day']==day]    
     
    return df


def time_stats(df):
    """Displays statistics on the most frequent times of travel."""

    print('\nCalculating The Most Frequent Times of Travel...\n')
    start_time = time.time()

    # TO DO: display the most common month
    most_frequent_month=df['month'].mode()[0]
    print(f'the most common month is :{most_frequent_month}')

    # TO DO: display the most common day of week
    most_frequent_day=df['day'].mode()[0]
    print(f'the mosta common day of the week is :{most_frequent_day}')   

    # TO DO: display the most common start hour
    most_frequent_hour = df['start_hour'].mode()[0]
    print(f'the most common start hour is :{most_frequent_hour}')

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)


def station_stats(df):
    """Displays statistics on the most popular stations and trip."""

    print('\nCalculating The Most Popular Stations and Trip...\n')
    start_time = time.time()

    # TO DO: display most commonly used start station

    print(f"the most common start station used is : {df['Start Station'].mode()[0]}")

    # TO DO: display most commonly used end station
    df['last station'] =df['End Station']
    print(f"the most commonly end station used is : {df['last station'].mode()[0]}")

    # TO DO: display most frequent combination of start station and end station trip
    df['the_used_way']=df['Start Station'] +'_'+df['End Station']
    print(f'the most commonly route used is : {df["the_used_way"].mode()[0]}')


    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)


def trip_duration_stats(df):
    """Displays statistics on the total and average trip duration."""

    print('\nCalculating Trip Duration...\n')
    start_time = time.time()

    # TO DO: display total travel time
    print(f'total travel time is :{df["Trip Duration"].sum().round()}')

    # TO DO: display mean travel time
    print(f'total mean trip duration is :{df["Trip Duration"].mean().round()}')

    
    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

# %%
def user_stats(df,city):
    """Displays statistics on bikeshare users."""

    print('\nCalculating User Stats...\n')
    start_time = time.time()

    # TO DO: Display counts of user types
    print(f'the count of users types is : {df["User Type"].value_counts().to_frame()}')
  

    # TO DO: Display counts of gender
    if city !='washington':
        print(f'show the counts of gender is :{df["Gender"].value_counts()}')
    else:
        print('there is no column cender in this city, please try another city')

        
    # TO DO: Display earliest, most recent, and most common year of birth
    if city != 'washington':
        print(f'show earliest year of birth is :{int(df["Birth Year"].min())}')
        print(f'show most common birth year is :{int(df["Birth Year"].mode())}')
        print(f'show most recent birth year is :{int(df["Birth Year"].max())}')
    else:
        print('there is no column gender pleae try anoter city')
        
        
    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)



def  disply_raw_data(df):
    # disply the first 5 rows of raw data and if you want more than 5 add word yes 
    user_enter= input('if you want to disply first 5 rows of data please type \nPrint yes or no: ').lower() 
      
        
    # if the answer not in yes or no 
    if user_enter not in ['yes','no']:
        while True:
            print('please enter :" yes or no"')
            user_enter= input('if you want to disply more than first 5 rows of data please type \nPrint yes or no: ').lower()
            if user_enter =='yes':
                print(df.head())
            else:
                break
    # if the answer is not no 
    elif user_enter =='no':
        print('there is no more data to disply')
      
    else:
        enter = 0
        while enter+5 < df.shape[0]:
            print(df.iloc[enter:enter+5])
            enter +=5
            user_enter= input('if you want to disply more than first 5 rows of data please type \nPrint yes or no: ').lower() 

            if user_enter != 'yes': 
                 print('there is no more data to display it')
                  
                 break
           
 

def main():
    while True:
        city, month, day = get_filters()
        df = load_data(city, month, day)

        time_stats(df)
        station_stats(df)
        trip_duration_stats(df)
        user_stats(df,city)
        disply_raw_data(df)
        restart = input('\nWould you like to restart? Enter yes or no.\n')
        if restart.lower() != 'yes':
            break
    
if __name__ == "__main__":
	main()
# Out:
# Hello! Let's explore some US bikeshare data!
# please input city(chicago, new york city, washington)chicago
# please input month (all, january, february, march,april,may , june)june
# please input day of week(all,monday ,tuesday,wendnesday,thrusday,friday,sunday)all
# ----------------------------------------
#
# Calculating The Most Frequent Times of Travel...
#
# the most common month is :6
# the mosta common day of the week is :4
# the most common start hour is :17
#
# This took 0.0069811344146728516 seconds.
# ----------------------------------------
#
# Calculating The Most Popular Stations and Trip...
#
# the most common start station used is : Streeter Dr & Grand Ave
# the most commonly end station used is : Streeter Dr & Grand Ave
# the most commonly route used is : Lake Shore Dr & Monroe St_Streeter Dr & Grand Ave
#
# This took 0.1085505485534668 seconds.
# ----------------------------------------
#
# Calculating Trip Duration...
#
# total travel time is :102702796
# ...
